# %%
from tensorflow.keras.models import model_from_json

with open('data/train/models/resnet_model.json', 'r') as json_file:
    model_json = json_file.read()
    model = model_from_json(model_json)

model.load_weights('data/train/models/resnet_model.h5')

# %%
import numpy as np

x_train = np.load('data/train/x_train.npy')
x_test = np.load('data/train/x_test.npy')
y_train = np.load('data/train/y_train.npy')
y_test = np.load('data/train/y_test.npy')

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 256, 256, 256, 1)]   0         []
#
#  conv3d_245 (Conv3D)         (None, 128, 128, 128, 64)    22016     ['input_6[0][0]']
#
#  batch_normalization_226 (B  (None, 128, 128, 128, 64)    256       ['conv3d_245[0][0]']
#  atchNormalization)
#
#  activation_225 (Activation  (None, 128, 128, 128, 64)    0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  max_pooling3d_5 (MaxPoolin  (None, 64, 64, 64, 64)       0         ['activation_225[0][0]']
#  g3D)
#
#  conv3d_246 (Conv3D)         (None, 64, 64, 64, 64)       4160      ['max_pooling3d_5[0][0]']
#
#  batch_normalization_227 (B  (None, 64, 64, 64, 64)       256       ['conv3d_246[0][0]']
#  atchNormalization)
#
#  activation_226 (Activation  (None, 64, 64, 64, 64)       0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  conv3d_247 (Conv3D)         (None, 64, 64, 64, 64)       110656    ['activation_226[0][0]']
#
#  batch_normalization_228 (B  (None, 64, 64, 64, 64)       256       ['conv3d_247[0][0]']
#  atchNormalization)
#
#  activation_227 (Activation  (None, 64, 64, 64, 64)       0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  conv3d_249 (Conv3D)         (None, 64, 64, 64, 256)      16640     ['max_pooling3d_5[0][0]']
#
#  conv3d_248 (Conv3D)         (None, 64, 64, 64, 256)      16640     ['activation_227[0][0]']
#
#  add_73 (Add)                (None, 64, 64, 64, 256)      0         ['conv3d_249[0][0]',
#                                                                      'conv3d_248[0][0]']
#
#  batch_normalization_229 (B  (None, 64, 64, 64, 256)      1024      ['add_73[0][0]']
#  atchNormalization)
#
#  activation_228 (Activation  (None, 64, 64, 64, 256)      0         ['batch_normalization_229[0][0
#  )                                                                  ]']
#
#  conv3d_250 (Conv3D)         (None, 64, 64, 64, 64)       16448     ['activation_228[0][0]']
#
#  batch_normalization_230 (B  (None, 64, 64, 64, 64)       256       ['conv3d_250[0][0]']
#  atchNormalization)
#
#  activation_229 (Activation  (None, 64, 64, 64, 64)       0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  conv3d_251 (Conv3D)         (None, 64, 64, 64, 64)       110656    ['activation_229[0][0]']
#
#  batch_normalization_231 (B  (None, 64, 64, 64, 64)       256       ['conv3d_251[0][0]']
#  atchNormalization)
#
#  activation_230 (Activation  (None, 64, 64, 64, 64)       0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  conv3d_252 (Conv3D)         (None, 64, 64, 64, 256)      16640     ['activation_230[0][0]']
#
#  add_74 (Add)                (None, 64, 64, 64, 256)      0         ['add_73[0][0]',
#                                                                      'conv3d_252[0][0]']
#
#  batch_normalization_232 (B  (None, 64, 64, 64, 256)      1024      ['add_74[0][0]']
#  atchNormalization)
#
#  activation_231 (Activation  (None, 64, 64, 64, 256)      0         ['batch_normalization_232[0][0
#  )                                                                  ]']
#
#  conv3d_253 (Conv3D)         (None, 64, 64, 64, 64)       16448     ['activation_231[0][0]']
#
#  batch_normalization_233 (B  (None, 64, 64, 64, 64)       256       ['conv3d_253[0][0]']
#  atchNormalization)
#
#  activation_232 (Activation  (None, 64, 64, 64, 64)       0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv3d_254 (Conv3D)         (None, 64, 64, 64, 64)       110656    ['activation_232[0][0]']
#
#  batch_normalization_234 (B  (None, 64, 64, 64, 64)       256       ['conv3d_254[0][0]']
#  atchNormalization)
#
#  activation_233 (Activation  (None, 64, 64, 64, 64)       0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv3d_255 (Conv3D)         (None, 64, 64, 64, 256)      16640     ['activation_233[0][0]']
#
#  add_75 (Add)                (None, 64, 64, 64, 256)      0         ['add_74[0][0]',
#                                                                      'conv3d_255[0][0]']
#
#  batch_normalization_235 (B  (None, 64, 64, 64, 256)      1024      ['add_75[0][0]']
#  atchNormalization)
#
#  activation_234 (Activation  (None, 64, 64, 64, 256)      0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  conv3d_256 (Conv3D)         (None, 32, 32, 32, 128)      32896     ['activation_234[0][0]']
#
#  batch_normalization_236 (B  (None, 32, 32, 32, 128)      512       ['conv3d_256[0][0]']
#  atchNormalization)
#
#  activation_235 (Activation  (None, 32, 32, 32, 128)      0         ['batch_normalization_236[0][0
#  )                                                                  ]']
#
#  conv3d_257 (Conv3D)         (None, 32, 32, 32, 128)      442496    ['activation_235[0][0]']
#
#  batch_normalization_237 (B  (None, 32, 32, 32, 128)      512       ['conv3d_257[0][0]']
#  atchNormalization)
#
#  activation_236 (Activation  (None, 32, 32, 32, 128)      0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  conv3d_259 (Conv3D)         (None, 32, 32, 32, 512)      131584    ['add_75[0][0]']
#
#  conv3d_258 (Conv3D)         (None, 32, 32, 32, 512)      66048     ['activation_236[0][0]']
#
#  add_76 (Add)                (None, 32, 32, 32, 512)      0         ['conv3d_259[0][0]',
#                                                                      'conv3d_258[0][0]']
#
#  batch_normalization_238 (B  (None, 32, 32, 32, 512)      2048      ['add_76[0][0]']
#  atchNormalization)
#
#  activation_237 (Activation  (None, 32, 32, 32, 512)      0         ['batch_normalization_238[0][0
#  )                                                                  ]']
#
#  conv3d_260 (Conv3D)         (None, 32, 32, 32, 128)      65664     ['activation_237[0][0]']
#
#  batch_normalization_239 (B  (None, 32, 32, 32, 128)      512       ['conv3d_260[0][0]']
#  atchNormalization)
#
#  activation_238 (Activation  (None, 32, 32, 32, 128)      0         ['batch_normalization_239[0][0
#  )                                                                  ]']
#
#  conv3d_261 (Conv3D)         (None, 32, 32, 32, 128)      442496    ['activation_238[0][0]']
#
#  batch_normalization_240 (B  (None, 32, 32, 32, 128)      512       ['conv3d_261[0][0]']
#  atchNormalization)
#
#  activation_239 (Activation  (None, 32, 32, 32, 128)      0         ['batch_normalization_240[0][0
#  )                                                                  ]']
#
#  conv3d_262 (Conv3D)         (None, 32, 32, 32, 512)      66048     ['activation_239[0][0]']
#
#  add_77 (Add)                (None, 32, 32, 32, 512)      0         ['add_76[0][0]',
#                                                                      'conv3d_262[0][0]']
#
#  batch_normalization_241 (B  (None, 32, 32, 32, 512)      2048      ['add_77[0][0]']
#  atchNormalization)
#
#  activation_240 (Activation  (None, 32, 32, 32, 512)      0         ['batch_normalization_241[0][0
#  )                                                                  ]']
#
#  conv3d_263 (Conv3D)         (None, 32, 32, 32, 128)      65664     ['activation_240[0][0]']
#
#  batch_normalization_242 (B  (None, 32, 32, 32, 128)      512       ['conv3d_263[0][0]']
#  atchNormalization)
#
#  activation_241 (Activation  (None, 32, 32, 32, 128)      0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  conv3d_264 (Conv3D)         (None, 32, 32, 32, 128)      442496    ['activation_241[0][0]']
#
#  batch_normalization_243 (B  (None, 32, 32, 32, 128)      512       ['conv3d_264[0][0]']
#  atchNormalization)
#
#  activation_242 (Activation  (None, 32, 32, 32, 128)      0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv3d_265 (Conv3D)         (None, 32, 32, 32, 512)      66048     ['activation_242[0][0]']
#
#  add_78 (Add)                (None, 32, 32, 32, 512)      0         ['add_77[0][0]',
#                                                                      'conv3d_265[0][0]']
#
#  batch_normalization_244 (B  (None, 32, 32, 32, 512)      2048      ['add_78[0][0]']
#  atchNormalization)
#
#  activation_243 (Activation  (None, 32, 32, 32, 512)      0         ['batch_normalization_244[0][0
#  )                                                                  ]']
#
#  conv3d_266 (Conv3D)         (None, 32, 32, 32, 128)      65664     ['activation_243[0][0]']
#
#  batch_normalization_245 (B  (None, 32, 32, 32, 128)      512       ['conv3d_266[0][0]']
#  atchNormalization)
#
#  activation_244 (Activation  (None, 32, 32, 32, 128)      0         ['batch_normalization_245[0][0
#  )                                                                  ]']
#
#  conv3d_267 (Conv3D)         (None, 32, 32, 32, 128)      442496    ['activation_244[0][0]']
#
#  batch_normalization_246 (B  (None, 32, 32, 32, 128)      512       ['conv3d_267[0][0]']
#  atchNormalization)
#
#  activation_245 (Activation  (None, 32, 32, 32, 128)      0         ['batch_normalization_246[0][0
#  )                                                                  ]']
#
#  conv3d_268 (Conv3D)         (None, 32, 32, 32, 512)      66048     ['activation_245[0][0]']
#
#  add_79 (Add)                (None, 32, 32, 32, 512)      0         ['add_78[0][0]',
#                                                                      'conv3d_268[0][0]']
#
#  batch_normalization_247 (B  (None, 32, 32, 32, 512)      2048      ['add_79[0][0]']
#  atchNormalization)
#
#  activation_246 (Activation  (None, 32, 32, 32, 512)      0         ['batch_normalization_247[0][0
#  )                                                                  ]']
#
#  conv3d_269 (Conv3D)         (None, 16, 16, 16, 256)      131328    ['activation_246[0][0]']
#
#  batch_normalization_248 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_269[0][0]']
#  atchNormalization)
#
#  activation_247 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_248[0][0
#  )                                                                  ]']
#
#  conv3d_270 (Conv3D)         (None, 16, 16, 16, 256)      1769728   ['activation_247[0][0]']
#
#  batch_normalization_249 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_270[0][0]']
#  atchNormalization)
#
#  activation_248 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_249[0][0
#  )                                                                  ]']
#
#  conv3d_272 (Conv3D)         (None, 16, 16, 16, 1024)     525312    ['add_79[0][0]']
#
#  conv3d_271 (Conv3D)         (None, 16, 16, 16, 1024)     263168    ['activation_248[0][0]']
#
#  add_80 (Add)                (None, 16, 16, 16, 1024)     0         ['conv3d_272[0][0]',
#                                                                      'conv3d_271[0][0]']
#
#  batch_normalization_250 (B  (None, 16, 16, 16, 1024)     4096      ['add_80[0][0]']
#  atchNormalization)
#
#  activation_249 (Activation  (None, 16, 16, 16, 1024)     0         ['batch_normalization_250[0][0
#  )                                                                  ]']
#
#  conv3d_273 (Conv3D)         (None, 16, 16, 16, 256)      262400    ['activation_249[0][0]']
#
#  batch_normalization_251 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_273[0][0]']
#  atchNormalization)
#
#  activation_250 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_251[0][0
#  )                                                                  ]']
#
#  conv3d_274 (Conv3D)         (None, 16, 16, 16, 256)      1769728   ['activation_250[0][0]']
#
#  batch_normalization_252 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_274[0][0]']
#  atchNormalization)
#
#  activation_251 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_252[0][0
#  )                                                                  ]']
#
#  conv3d_275 (Conv3D)         (None, 16, 16, 16, 1024)     263168    ['activation_251[0][0]']
#
#  add_81 (Add)                (None, 16, 16, 16, 1024)     0         ['add_80[0][0]',
#                                                                      'conv3d_275[0][0]']
#
#  batch_normalization_253 (B  (None, 16, 16, 16, 1024)     4096      ['add_81[0][0]']
#  atchNormalization)
#
#  activation_252 (Activation  (None, 16, 16, 16, 1024)     0         ['batch_normalization_253[0][0
#  )                                                                  ]']
#
#  conv3d_276 (Conv3D)         (None, 16, 16, 16, 256)      262400    ['activation_252[0][0]']
#
#  batch_normalization_254 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_276[0][0]']
#  atchNormalization)
#
#  activation_253 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_254[0][0
#  )                                                                  ]']
#
#  conv3d_277 (Conv3D)         (None, 16, 16, 16, 256)      1769728   ['activation_253[0][0]']
#
#  batch_normalization_255 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_277[0][0]']
#  atchNormalization)
#
#  activation_254 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_255[0][0
#  )                                                                  ]']
#
#  conv3d_278 (Conv3D)         (None, 16, 16, 16, 1024)     263168    ['activation_254[0][0]']
#
#  add_82 (Add)                (None, 16, 16, 16, 1024)     0         ['add_81[0][0]',
#                                                                      'conv3d_278[0][0]']
#
#  batch_normalization_256 (B  (None, 16, 16, 16, 1024)     4096      ['add_82[0][0]']
#  atchNormalization)
#
#  activation_255 (Activation  (None, 16, 16, 16, 1024)     0         ['batch_normalization_256[0][0
#  )                                                                  ]']
#
#  conv3d_279 (Conv3D)         (None, 16, 16, 16, 256)      262400    ['activation_255[0][0]']
#
#  batch_normalization_257 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_279[0][0]']
#  atchNormalization)
#
#  activation_256 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_257[0][0
#  )                                                                  ]']
#
#  conv3d_280 (Conv3D)         (None, 16, 16, 16, 256)      1769728   ['activation_256[0][0]']
#
#  batch_normalization_258 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_280[0][0]']
#  atchNormalization)
#
#  activation_257 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_258[0][0
#  )                                                                  ]']
#
#  conv3d_281 (Conv3D)         (None, 16, 16, 16, 1024)     263168    ['activation_257[0][0]']
#
#  add_83 (Add)                (None, 16, 16, 16, 1024)     0         ['add_82[0][0]',
#                                                                      'conv3d_281[0][0]']
#
#  batch_normalization_259 (B  (None, 16, 16, 16, 1024)     4096      ['add_83[0][0]']
#  atchNormalization)
#
#  activation_258 (Activation  (None, 16, 16, 16, 1024)     0         ['batch_normalization_259[0][0
#  )                                                                  ]']
#
#  conv3d_282 (Conv3D)         (None, 16, 16, 16, 256)      262400    ['activation_258[0][0]']
#
#  batch_normalization_260 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_282[0][0]']
#  atchNormalization)
#
#  activation_259 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_260[0][0
#  )                                                                  ]']
#
#  conv3d_283 (Conv3D)         (None, 16, 16, 16, 256)      1769728   ['activation_259[0][0]']
#
#  batch_normalization_261 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_283[0][0]']
#  atchNormalization)
#
#  activation_260 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_261[0][0
#  )                                                                  ]']
#
#  conv3d_284 (Conv3D)         (None, 16, 16, 16, 1024)     263168    ['activation_260[0][0]']
#
#  add_84 (Add)                (None, 16, 16, 16, 1024)     0         ['add_83[0][0]',
#                                                                      'conv3d_284[0][0]']
#
#  batch_normalization_262 (B  (None, 16, 16, 16, 1024)     4096      ['add_84[0][0]']
#  atchNormalization)
#
#  activation_261 (Activation  (None, 16, 16, 16, 1024)     0         ['batch_normalization_262[0][0
#  )                                                                  ]']
#
#  conv3d_285 (Conv3D)         (None, 16, 16, 16, 256)      262400    ['activation_261[0][0]']
#
#  batch_normalization_263 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_285[0][0]']
#  atchNormalization)
#
#  activation_262 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_263[0][0
#  )                                                                  ]']
#
#  conv3d_286 (Conv3D)         (None, 16, 16, 16, 256)      1769728   ['activation_262[0][0]']
#
#  batch_normalization_264 (B  (None, 16, 16, 16, 256)      1024      ['conv3d_286[0][0]']
#  atchNormalization)
#
#  activation_263 (Activation  (None, 16, 16, 16, 256)      0         ['batch_normalization_264[0][0
#  )                                                                  ]']
#
#  conv3d_287 (Conv3D)         (None, 16, 16, 16, 1024)     263168    ['activation_263[0][0]']
#
#  add_85 (Add)                (None, 16, 16, 16, 1024)     0         ['add_84[0][0]',
#                                                                      'conv3d_287[0][0]']
#
#  batch_normalization_265 (B  (None, 16, 16, 16, 1024)     4096      ['add_85[0][0]']
#  atchNormalization)
#
#  activation_264 (Activation  (None, 16, 16, 16, 1024)     0         ['batch_normalization_265[0][0
#  )                                                                  ]']
#
#  conv3d_288 (Conv3D)         (None, 8, 8, 8, 512)         524800    ['activation_264[0][0]']
#
#  batch_normalization_266 (B  (None, 8, 8, 8, 512)         2048      ['conv3d_288[0][0]']
#  atchNormalization)
#
#  activation_265 (Activation  (None, 8, 8, 8, 512)         0         ['batch_normalization_266[0][0
#  )                                                                  ]']
#
#  conv3d_289 (Conv3D)         (None, 8, 8, 8, 512)         7078400   ['activation_265[0][0]']
#
#  batch_normalization_267 (B  (None, 8, 8, 8, 512)         2048      ['conv3d_289[0][0]']
#  atchNormalization)
#
#  activation_266 (Activation  (None, 8, 8, 8, 512)         0         ['batch_normalization_267[0][0
#  )                                                                  ]']
#
#  conv3d_291 (Conv3D)         (None, 8, 8, 8, 2048)        2099200   ['add_85[0][0]']
#
#  conv3d_290 (Conv3D)         (None, 8, 8, 8, 2048)        1050624   ['activation_266[0][0]']
#
#  add_86 (Add)                (None, 8, 8, 8, 2048)        0         ['conv3d_291[0][0]',
#                                                                      'conv3d_290[0][0]']
#
#  batch_normalization_268 (B  (None, 8, 8, 8, 2048)        8192      ['add_86[0][0]']
#  atchNormalization)
#
#  activation_267 (Activation  (None, 8, 8, 8, 2048)        0         ['batch_normalization_268[0][0
#  )                                                                  ]']
#
#  conv3d_292 (Conv3D)         (None, 8, 8, 8, 512)         1049088   ['activation_267[0][0]']
#
#  batch_normalization_269 (B  (None, 8, 8, 8, 512)         2048      ['conv3d_292[0][0]']
#  atchNormalization)
#
#  activation_268 (Activation  (None, 8, 8, 8, 512)         0         ['batch_normalization_269[0][0
#  )                                                                  ]']
#
#  conv3d_293 (Conv3D)         (None, 8, 8, 8, 512)         7078400   ['activation_268[0][0]']
#
#  batch_normalization_270 (B  (None, 8, 8, 8, 512)         2048      ['conv3d_293[0][0]']
#  atchNormalization)
#
#  activation_269 (Activation  (None, 8, 8, 8, 512)         0         ['batch_normalization_270[0][0
#  )                                                                  ]']
#
#  conv3d_294 (Conv3D)         (None, 8, 8, 8, 2048)        1050624   ['activation_269[0][0]']
#
#  add_87 (Add)                (None, 8, 8, 8, 2048)        0         ['add_86[0][0]',
#                                                                      'conv3d_294[0][0]']
#
#  batch_normalization_271 (B  (None, 8, 8, 8, 2048)        8192      ['add_87[0][0]']
#  atchNormalization)
#
#  activation_270 (Activation  (None, 8, 8, 8, 2048)        0         ['batch_normalization_271[0][0
#  )                                                                  ]']
#
#  conv3d_295 (Conv3D)         (None, 8, 8, 8, 512)         1049088   ['activation_270[0][0]']
#
#  batch_normalization_272 (B  (None, 8, 8, 8, 512)         2048      ['conv3d_295[0][0]']
#  atchNormalization)
#
#  activation_271 (Activation  (None, 8, 8, 8, 512)         0         ['batch_normalization_272[0][0
#  )                                                                  ]']
#
#  conv3d_296 (Conv3D)         (None, 8, 8, 8, 512)         7078400   ['activation_271[0][0]']
#
#  batch_normalization_273 (B  (None, 8, 8, 8, 512)         2048      ['conv3d_296[0][0]']
#  atchNormalization)
#
#  activation_272 (Activation  (None, 8, 8, 8, 512)         0         ['batch_normalization_273[0][0
#  )                                                                  ]']
#
#  conv3d_297 (Conv3D)         (None, 8, 8, 8, 2048)        1050624   ['activation_272[0][0]']
#
#  add_88 (Add)                (None, 8, 8, 8, 2048)        0         ['add_87[0][0]',
#                                                                      'conv3d_297[0][0]']
#
#  batch_normalization_274 (B  (None, 8, 8, 8, 2048)        8192      ['add_88[0][0]']
#  atchNormalization)
#
#  activation_273 (Activation  (None, 8, 8, 8, 2048)        0         ['batch_normalization_274[0][0
#  )                                                                  ]']
#
#  average_pooling3d_4 (Avera  (None, 1, 1, 1, 2048)        0         ['activation_273[0][0]']
#  gePooling3D)
#
#  flatten_4 (Flatten)         (None, 2048)                 0         ['average_pooling3d_4[0][0]']
#
#  dense_4 (Dense)             (None, 15)                   30735     ['flatten_4[0][0]']
#
# ==================================================================================================
# Total params: 46250127 (176.43 MB)
# Trainable params: 46204687 (176.26 MB)
# Non-trainable params: 45440 (177.50 KB)
# __________________________________________________________________________________________________

# %%
y_test_predictions = model.predict(x_test)
# Out:
# 1/1 [==============================] - 7s 7s/step

# %%
y_test_predictions[0].shape
# Out:
# (15,)

# %%
print(y_test_predictions[0])
# Out:
# [7.3087621e-12 3.5803769e-12 3.1256677e-06 3.3949120e-12 4.3480011e-12
#  1.9287043e-06 3.2735036e-12 4.2443805e-12 6.5631184e-07 1.3634442e-12
#  2.9743916e-12 6.0449047e-06 1.2875198e-11 3.4103126e-12 9.9998820e-01]
