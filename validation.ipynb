# %%
from tensorflow.keras.models import model_from_json

with open('data/train/models/simple_resnet_model.json', 'r') as json_file:
    model_json = json_file.read()
    model = model_from_json(model_json)

model.load_weights('data/train/models/simple_resnet_model.h5')

# %%
import numpy as np

x_train = np.load('data/train/x_train.npy')
x_test = np.load('data/train/x_test.npy')
y_train = np.load('data/train/y_train.npy')
y_test = np.load('data/train/y_test.npy')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 256, 256, 256, 1)]   0         []
#
#  conv3d (Conv3D)             (None, 128, 128, 128, 64)    22016     ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 128, 64)    256       ['conv3d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 128, 128, 128, 64)    0         ['batch_normalization[0][0]']
#
#  max_pooling3d (MaxPooling3  (None, 64, 64, 64, 64)       0         ['activation[0][0]']
#  D)
#
#  conv3d_1 (Conv3D)           (None, 64, 64, 64, 64)       4160      ['max_pooling3d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 64, 64, 64)       256       ['conv3d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 64, 64, 64, 64)       0         ['batch_normalization_1[0][0]'
# ...

# %%
y_test_predictions = model.predict(x_test)
# Out:
# 1/1 [==============================] - 7s 7s/step

# %%
y_test_predictions[0].shape
# Out:
# (256,)

# %%
print(y_test_predictions[0])
# Out:
# [4.1434716e-04 4.5360872e-04 4.1662593e-04 5.1782752e-04 4.1302413e-04
#  4.9325521e-04 4.0851874e-04 4.5700622e-04 4.4424075e-04 4.7187079e-04
#  3.6384238e-04 4.7787649e-04 3.9499800e-04 5.1962200e-04 4.3077808e-04
#  4.2929061e-04 4.8476469e-04 3.9615636e-04 4.3394827e-04 4.4627645e-04
#  4.0638429e-04 4.5072474e-04 3.9163846e-04 4.7584096e-04 4.2274472e-04
#  4.5602536e-04 3.9355131e-04 4.3297149e-04 4.1492586e-04 4.0180763e-04
#  4.0762327e-04 5.0915434e-04 4.0505247e-04 3.9606739e-04 5.1824178e-04
#  4.2639507e-04 3.8411698e-04 6.0301099e-04 4.6901716e-04 4.8057592e-04
#  5.4536969e-04 5.1257620e-04 4.7270834e-04 5.5543898e-04 4.5963816e-04
#  4.3370153e-04 4.3242821e-04 5.2723562e-04 3.8961152e-04 4.7637857e-04
#  4.7873272e-04 4.2736845e-04 4.7859669e-04 4.8865768e-04 5.7701953e-04
#  5.1280844e-04 5.0007389e-04 5.1152776e-04 5.1206362e-04 5.9516722e-04
#  5.6973309e-04 5.9845840e-04 6.1393162e-04 5.0477259e-04 6.0280197e-04
# ...
